# %%
import pandas as pd
import numpy as np

#Local_Authority_Highway_codes
lahc = ['E09000013','E09000014','E09000015']


#Load the Dataset
df = pd.read_csv('AccidentLondonBoroughs.csv')

# %%
#Formating tyes
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M')

#transform Date and Time values into ints

dateMaxMin = [df['Date'].max(), df['Date'].min()]
timeMaxMin = [df['Time'].max(), df['Time'].min()]

dateDelta = dateMaxMin[0] - dateMaxMin[1]
numOfDays = dateDelta.days

timeDelta = timeMaxMin[0] - timeMaxMin[1]
numOfMins = timeDelta.total_seconds() / 60

dateVals = []
for i in df['Date']:
    delt = i - dateMaxMin[1]
    val = delt.days
    dateVals.append(val)
    
timeVals = []
for i in df['Time']:
    delt = i - timeMaxMin[1]
    val = int(delt.total_seconds() / 60)
    timeVals.append(val)
    
df.drop(columns = ['Date', 'Time'], inplace = True)
    
df['DateVals'] = dateVals
df['TimeVals'] = timeVals


print('dateStart: ' + str(dateMaxMin[1].date()) + '\n' 
      + 'dateEnd: ' + str(dateMaxMin[0].date()) + '\n' 
      + 'totalDays: ' + str(numOfDays) + '\n' 
      + 'timeStart: ' + str(timeMaxMin[1].time()) + '\n'
      + 'timeEnd: ' + str(timeMaxMin[0].time()) + '\n'
      + 'totalMins: ' +  str(numOfMins))
# Out:
# dateStart: 2005-01-01
# dateEnd: 2010-12-31
# totalDays: 2190
# timeStart: 00:01:00
# timeEnd: 23:59:00
# totalMins: 1438.0

# %%
#get columns associated with the LAHC
data = pd.DataFrame(columns = df.columns.to_list())
dfDict = dict(df.dtypes)

for key, val in dfDict.items():
    if val == 'int64' or val == 'float64':
        data[key] = pd.to_numeric(data[key])
    
for lac in lahc :
    lacRows = df.loc[df['Local_Authority_(Highway)'] == lac]
    data = pd.concat([data, lacRows])

# %%
# raw, unclean, with outliers data
data.shape
# Out:
# (10681, 32)

# %%
class ColumnAttri:
    def __init__(self, name, ctype):
        self.name = name
        self.ctype = str(ctype)
        self.range = []
        self.values = []
        self.empty = 0
        self.notEmpty = 0
        
    def processCol(self, data):
        for row in data[self.name]:
            if row == -1 or str(row) == '-1':
                self.empty += 1
                continue
            self.notEmpty += 1
            
            if self.ctype == 'int64' or self.ctype == 'float64':
                if len(self.range) >= 1:
                    if self.range[0] > row:
                        self.range[0] = row
                    if self.range[1] < row:
                        self.range[1] = row
                else:
                    self.range.append(row)
                    self.range.append(row)
                    
            if self.name == 'Date' or self.name == 'Time':
                if len(self.range) >= 1:
                    if self.range[0] > row:
                        self.range[0] = row
                    if self.range[1] < row:
                        self.range[1] = row
                else:
                    self.range.append(row)
                    self.range.append(row)
                    
            if not row in self.values:
                self.values.append(row)
                
    def presentColAttri(self):
        numerics = ['float64', 'int64' , 'datetime64[ns]']
        
        if not self.ctype in numerics:
            self.range = ['Nan', 'Nan']
        attri = {'Name': self.name, 'Type': self.ctype, 'Empty': self.empty, 'Full': self.notEmpty, 'Ratio': (self.empty / 10681) * 100, 'Min': self.range[0], 'Max': self.range[1], 'Unique': len(self.values)}
        return attri
    
    def getValues(self):
        return self.values

# %%
def analyzeDF(dat):
    ColAttributes = []
    dataDict = dict(dat.dtypes)

    for key, val in dataDict.items():
        currCol = ColumnAttri(key, val)
        currCol.processCol(dat)
        ColAttributes.append(currCol)

    colDF = pd.DataFrame(columns=['Name','Type', 'Empty', 'Full', 'Ratio', 'Min', 'Max', 'Unique'])

    for col in ColAttributes:
        colDF = colDF.append(col.presentColAttri(), ignore_index=True)

    print(colDF.shape)
    return colDF

# %%
#allSampsDF = analyzeDF(df)
#allSampsDF

# %%
anaDF1 = analyzeDF(data)
anaDF1
# Out:
# (32, 8)
#                                            Name     Type Empty   Full  \
# 0                                Accident_Index   object     0  10681
# 1                         Location_Easting_OSGR    int64     0  10681
# 2                        Location_Northing_OSGR    int64     0  10681
# 3                                     Longitude  float64     0  10681
# 4                                      Latitude  float64     0  10681
# 5                                  Police_Force    int64     0  10681
# 6                             Accident_Severity    int64     0  10681
# 7                            Number_of_Vehicles    int64     0  10681
# 8                          Number_of_Casualties    int64     0  10681
# 9                                   Day_of_Week    int64     0  10681
# 10                   Local_Authority_(District)    int64     0  10681
# 11                    Local_Authority_(Highway)   object     0  10681
# 12                               1st_Road_Class    int64     0  10681
# 13                              1st_Road_Number    int64     0  10681
# 14                                    Road_Type    int64     0  10681
# 15                                  Speed_limit    int64     0  10681
# 16                              Junction_Detail    int64     0  10681
# 17                             Junction_Control    int64  2903   7778
# 18                               2nd_Road_Class    int64  2904   7777
# 19                              2nd_Road_Number    int64     1  10680
# 20            Pedestrian_Crossing-Human_Control    int64     0  10681
# 21      Pedestrian_Crossing-Physical_Facilities    int64     0  10681
# 22                             Light_Conditions    int64     0  10681
# 23                           Weather_Conditions    int64     0  10681
# 24                      Road_Surface_Conditions    int64     1  10680
# 25                   Special_Conditions_at_Site    int64     0  10681
# 26                          Carriageway_Hazards    int64     1  10680
# 27                          Urban_or_Rural_Area    int64     0  10681
# 28  Did_Police_Officer_Attend_Scene_of_Accident    int64     0  10681
# 29                    LSOA_of_Accident_Location   object     0  10681
# 30                                     DateVals    int64     0  10681
# 31                                     TimeVals    int64     0  10681
#
#         Ratio       Min        Max Unique
# 0    0.000000       Nan        Nan  10681
# 1    0.000000    510800     535190   1876
# 2    0.000000    175590     193940   1295
# 3    0.000000 -0.401384  -0.049164   7192
# 4    0.000000  51.46535  51.632397   6989
# 5    0.000000         1          1      1
# 6    0.000000         1          3      3
# 7    0.000000         1          8      7
# 8    0.000000         1          9      7
# 9    0.000000         1          7      7
# 10   0.000000        11         31      3
# 11   0.000000       Nan        Nan      3
# 12   0.000000         3          6      4
# 13   0.000000         0       4140     56
# 14   0.000000         1          9      6
# 15   0.000000        20         60      5
# 16   0.000000         0          9      9
# 17  27.179103         1          4      4
# 18  27.188465         3          6      4
# 19   0.009362         0       4140     56
# 20   0.000000         0          2      3
# 21   0.000000         0          8      6
# 22   0.000000         1          7      5
# 23   0.000000         1          9      9
# 24   0.009362         1          5      5
# 25   0.000000         0          7      8
# 26   0.009362         0          7      6
# 27   0.000000         1          2      2
# 28   0.000000         1          3      3
# 29   0.000000       Nan        Nan    413
# 30   0.000000         0       2190   2149
# 31   0.000000         0       1438   1252

# %%
df['Speed_limit'].unique()
# Out:
# array([30, 40, 50, 20, 60, 70, 10, 15])

# %%
colsWithMissing = ['Carriageway_Hazards', '2nd_Road_Number', 'Road_Surface_Conditions']
rwIndxs = []

for i in colsWithMissing:
    rwIndxs = rwIndxs + data.loc[data[i] == -1].index.to_list()

data.drop(rwIndxs, inplace=True)
data.shape
# Out:
# (10679, 32)

# %%
#identify repeat vals/cols

def testIfIdentic(dat, col1, col2):
    flag = True
    similar = 0
    different = 0
    total = 0
    col1vals = []
    col2vals = []
    
    if(len(dat[col1].unique()) != len(dat[col2].unique())):
        vals = {0: False, 1: 0, 2: 0, 3: False}
        return vals
    
    for i in dat.index.tolist():
        x = dat.at[i, col1]
        y = dat.at[i, col2]
        
        if(x == -1 or y == -1):
            continue
        
        if(x in col1vals):
            indx = col1vals.index(x)
            if(col2vals[indx] != y):
                different += 1
                flag = False
            else:
                similar += 1
        else:
            col1vals.append(x)
            col2vals.append(y)
        total += 1
        
    vals = {0: flag, 1: similar, 2: different, 3: True}
    
    return vals

# %%
identicAttriDF = pd.DataFrame(columns=['col1', 'col2', 'isIdentic', 'similar', 'different'])

colNames = list(dict(data.dtypes).keys())
done = []
    
for a in colNames:
    for b in colNames:
        if (a == b or a in done):
            continue
        test = testIfIdentic(data, a, b)
        if (test[3] == False):
            continue
        vals = {'col1': a, 'col2': b, 'isIdentic': test[0], 'similar': test[1], 'different': test[2]}
        identicAttriDF = identicAttriDF.append(vals, ignore_index = True)
    done.append(a)
    
identicAttriDF.shape
# Out:
# (56, 5)

# %%
identicAttriDF.loc[identicAttriDF['isIdentic'] ==  True]
# Out:
#                           col1                        col2 isIdentic similar  \
# 11  Local_Authority_(District)   Local_Authority_(Highway)      True   10676
# 15   Local_Authority_(Highway)  Local_Authority_(District)      True   10676
#
#    different
# 11         0
# 15         0

# %%
#drop police force atribut because all entries have same value
#drop Junction_control and 2nd_road_class beacuse they have over 20% missing entries

data.drop(columns=['Police_Force', 'Junction_Control', '2nd_Road_Class', 'Local_Authority_(District)'], inplace=True)

# %%
identicAttriDF.sort_values(by= ['similar'])
# Out:
#                                            col1  \
# 34                              2nd_Road_Number
# 48                      Road_Surface_Conditions
# 22                                  Speed_limit
# 27                             Junction_Control
# 43                             Light_Conditions
# 7                          Number_of_Casualties
# 5                            Number_of_Vehicles
# 28                             Junction_Control
# 45                           Weather_Conditions
# 23                                  Speed_limit
# 49                      Road_Surface_Conditions
# 53  Did_Police_Officer_Attend_Scene_of_Accident
# 37            Pedestrian_Crossing-Human_Control
# 36            Pedestrian_Crossing-Human_Control
# 54  Did_Police_Officer_Attend_Scene_of_Accident
# 0                             Accident_Severity
# 1                             Accident_Severity
# 32                               2nd_Road_Class
# 25                              Junction_Detail
# 17                    Local_Authority_(Highway)
# 13                   Local_Authority_(District)
# 8                                   Day_of_Week
# 31                               2nd_Road_Class
# 33                               2nd_Road_Class
# 10                   Local_Authority_(District)
# 14                    Local_Authority_(Highway)
# 21                                  Speed_limit
# 42                             Light_Conditions
# 47                      Road_Surface_Conditions
# 29                             Junction_Control
# 6                          Number_of_Casualties
# 39      Pedestrian_Crossing-Physical_Facilities
# 18                              1st_Road_Number
# 51                          Carriageway_Hazards
# 19                                    Road_Type
# 30                               2nd_Road_Class
# 26                             Junction_Control
# 24                                  Speed_limit
# 44                             Light_Conditions
# 3                             Accident_Severity
# 38            Pedestrian_Crossing-Human_Control
# 9                                   Day_of_Week
# 4                            Number_of_Vehicles
# 50                          Carriageway_Hazards
# 35            Pedestrian_Crossing-Human_Control
# 52  Did_Police_Officer_Attend_Scene_of_Accident
# 46                      Road_Surface_Conditions
# 41                             Light_Conditions
# 40      Pedestrian_Crossing-Physical_Facilities
# 20                                    Road_Type
# 16                    Local_Authority_(Highway)
# 12                   Local_Authority_(District)
# 2                             Accident_Severity
# 55  Did_Police_Officer_Attend_Scene_of_Accident
# 15                    Local_Authority_(Highway)
# 11                   Local_Authority_(District)
#
#                                            col2 isIdentic similar different
# 34                              1st_Road_Number     False     817      9806
# 48                               2nd_Road_Class     False    1432      6340
# 22                               2nd_Road_Class     False    1561      6211
# 27                               2nd_Road_Class     False    1562      6211
# 43                               2nd_Road_Class     False    1569      6203
# 7                                   Day_of_Week     False    1624      9048
# 5                                   Day_of_Week     False    1671      9001
# 28                             Light_Conditions     False    2835      4938
# 45                              Junction_Detail     False    3124      7546
# 23                             Light_Conditions     False    3188      7486
# 49                             Light_Conditions     False    3213      7461
# 53                   Local_Authority_(District)     False    3882      6794
# 37                    Local_Authority_(Highway)     False    3882      6794
# 36                   Local_Authority_(District)     False    3882      6794
# 54                    Local_Authority_(Highway)     False    3882      6794
# 0                    Local_Authority_(District)     False    3882      6794
# 1                     Local_Authority_(Highway)     False    3882      6794
# 32                             Light_Conditions     False    4591      3182
# 25                           Weather_Conditions     False    5316      5354
# 17  Did_Police_Officer_Attend_Scene_of_Accident     False    5324      5352
# 13  Did_Police_Officer_Attend_Scene_of_Accident     False    5324      5352
# 8                            Number_of_Vehicles     False    5467      5205
# 31                             Junction_Control     False    5863      1910
# 33                      Road_Surface_Conditions     False    5969      1804
# 10                            Accident_Severity     False    6025      4651
# 14                            Accident_Severity     False    6025      4651
# 21                             Junction_Control     False    6051      1721
# 42                             Junction_Control     False    6066      1706
# 47                             Junction_Control     False    6067      1705
# 29                      Road_Surface_Conditions     False    6272      1501
# 6                            Number_of_Vehicles     False    6483      4189
# 39                                    Road_Type     False    7173      3500
# 18                              2nd_Road_Number     False    7364      3259
# 51      Pedestrian_Crossing-Physical_Facilities     False    7396      3277
# 19      Pedestrian_Crossing-Physical_Facilities     False    7425      3248
# 30                                  Speed_limit     False    7630       143
# 26                                  Speed_limit     False    7630       143
# 24                      Road_Surface_Conditions     False    8623      2051
# 44                      Road_Surface_Conditions     False    8673      2001
# 3   Did_Police_Officer_Attend_Scene_of_Accident     False    8705      1971
# 38  Did_Police_Officer_Attend_Scene_of_Accident     False    8705      1971
# 9                          Number_of_Casualties     False    9121      1551
# 4                          Number_of_Casualties     False    9122      1550
# 50                                    Road_Type     False    9220      1453
# 35                            Accident_Severity     False    9280      1396
# 52                            Accident_Severity     False    9282      1394
# 46                                  Speed_limit     False   10389       285
# 41                                  Speed_limit     False   10389       285
# 40                          Carriageway_Hazards     False   10607        66
# 20                          Carriageway_Hazards     False   10607        66
# 16            Pedestrian_Crossing-Human_Control     False   10657        19
# 12            Pedestrian_Crossing-Human_Control     False   10657        19
# 2             Pedestrian_Crossing-Human_Control     False   10657        19
# 55            Pedestrian_Crossing-Human_Control     False   10657        19
# 15                   Local_Authority_(District)      True   10676         0
# 11                    Local_Authority_(Highway)      True   10676         0

# %%
sim = testIfIdentic(df, 'Local_Authority_(District)', 'Local_Authority_(Highway)')
print(sim)
# Out:
# {0: True, 1: 145189, 2: 0, 3: True}

# %%
binary = {'Urban_or_Rural_Area'}
nomial = {'Did_Police_Officer_Attend_Scene_of_Accident', 'Local_Authority_(Highway)', '1st_Road_Class', 'Pedestrian_Crossing-Human_Control', 'Pedestrian_Crossing-Physical_Facilities', 'Junction_Detail', 'Road_Type'}
ordinal = {'Accident_Severity', 'Day_of_Week', 'Speed_limit'}
interval = {'DateVals', 'TimeVals', 'Number_of_Vehicles', 'Number_of_Casualties'}
ratio = {'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Latitude', 'Longitude'}
identifier = {'Accident_index'}

# %%
# clean data with outliers
data.shape
# Out:
# (10679, 28)

# %%
# finding outliers 
excludeCol = {'Accident_Index', 'Location_Easting_OSGR', 'Location_Northing_OSGR', 'Longitude', 'Latitude', 'Local_Authority_(Highway)', 'Local_Authority_(District)', 'LSOA_of_Accident_Location', '1st_Road_Number', '2nd_Road_Number'}
numericCol = {'Number_of_Casualties', 'Number_of_Vehicles', 'DateVals', 'TimeVals' }
categorCol = (set(data.columns.to_list()) - numericCol) - excludeCol

# %%
# outlier detectioction of numeric Cols: colName, std, mean, lower, upper, numOfOutliers
outNumData = pd.DataFrame(columns=['name', 'std', 'mean', 'lower', 'upper', 'numOfOutliers'])
outNumIndex = []

for i in numericCol:
    
    std = data[i].std()
    mean = data[i].mean()
    lower = mean - 3 * std
    upper = mean + 3 * std
    count = 0
    
    for row in data[i]:
        if ((row < lower) | (row > upper)):
            count += 1
            
    if (count == 0):
        continue
    
    vals = {'name':i, 'std':std, 'mean':mean, 'lower':lower, 'upper':upper, 'numOfOutliers':count}
    outNumData = outNumData.append(vals, ignore_index=True)
    
outNumData
# Out:
#                    name       std      mean     lower     upper numOfOutliers
# 0  Number_of_Casualties  0.563963  1.195898 -0.495990  2.887787           351
# 1    Number_of_Vehicles  0.616023  1.761026 -0.087044  3.609097           111

# %%
#finding Threshold for Categorical cols using numeric outlier results
numOfRows = data.shape[0]

thrshldCalc = [0, 0]
for i in outNumData['numOfOutliers']:
    thrshldCalc[0] += i
    thrshldCalc[1] += 1
    
thrshld = thrshldCalc[0] / thrshldCalc[1]

avgTPerc = thrshld / numOfRows
lwrTPerc = outNumData['numOfOutliers'].min() / numOfRows
print(numOfRows, avgTPerc, lwrTPerc)
# Out:
# 10679 0.021631238880044947 0.010394231669631987

# %%
# outlier detectioction of categorical Cols: colName, value, rate
outCatData = pd.DataFrame(columns=['name', 'value', 'number', 'rate'])

percent = lwrTPerc

for i in categorCol:
    
    colValDict = dict(data[i].value_counts())
    
    for v in colValDict.keys():
        
        if(v == -1):
            continue
        
        
        if(colValDict[v] / numOfRows < percent):
            vals = {'name': i, 'value':v, 'number': colValDict[v], 'rate':(colValDict[v] / numOfRows) * 100}
            outCatData = outCatData.append(vals, ignore_index=True)

outCatData.sort_values(by=['name'], inplace=True)
outCatData
# Out:
#                                            name value number      rate
# 28                            Accident_Severity     1     71  0.664856
# 29                          Carriageway_Hazards     2     36  0.337110
# 33                          Carriageway_Hazards     3      5  0.046821
# 32                          Carriageway_Hazards     1      5  0.046821
# 31                          Carriageway_Hazards     6      8  0.074913
# 30                          Carriageway_Hazards     7     12  0.112370
# 10  Did_Police_Officer_Attend_Scene_of_Accident     3     63  0.589943
# 6                               Junction_Detail     9     92  0.861504
# 7                               Junction_Detail     5     71  0.664856
# 15                             Light_Conditions     6      7  0.065549
# 13                             Light_Conditions     7     35  0.327746
# 14                             Light_Conditions     5     16  0.149827
# 12            Pedestrian_Crossing-Human_Control     1      4  0.037457
# 11            Pedestrian_Crossing-Human_Control     2     15  0.140463
# 26      Pedestrian_Crossing-Physical_Facilities     8     47  0.440116
# 27      Pedestrian_Crossing-Physical_Facilities     7     10  0.093642
# 17                      Road_Surface_Conditions     3     22  0.206012
# 18                      Road_Surface_Conditions     5      1  0.009364
# 16                      Road_Surface_Conditions     4     69  0.646128
# 8                                     Road_Type     7     46  0.430752
# 9                                     Road_Type     9     20  0.187283
# 19                   Special_Conditions_at_Site     4     71  0.664856
# 21                   Special_Conditions_at_Site     5     13  0.121734
# 22                   Special_Conditions_at_Site     1     12  0.112370
# 23                   Special_Conditions_at_Site     3      5  0.046821
# 24                   Special_Conditions_at_Site     2      2  0.018728
# 25                   Special_Conditions_at_Site     7      1  0.009364
# 20                   Special_Conditions_at_Site     6     15  0.140463
# 34                                  Speed_limit    50     58  0.543122
# 36                                  Speed_limit    60      2  0.018728
# 35                                  Speed_limit    20     19  0.177919
# 5                            Weather_Conditions     6      6  0.056185
# 4                            Weather_Conditions     7     19  0.177919
# 3                            Weather_Conditions     5     42  0.393295
# 2                            Weather_Conditions     3     42  0.393295
# 1                            Weather_Conditions     4     44  0.412024
# 0                            Weather_Conditions     9     66  0.618035

# %%
# Oulier Categorical descriptive df: colName, numOfValues
outDescData = pd.DataFrame(columns=['name', 'flaggedVals', 'totalVals', 'flaggedPerc', 'dominant'])
percDict = dict.fromkeys(outCatData['name'].unique().tolist(), 0)

for i in outCatData['name'].unique().tolist():
    num = 0
    
    for p in outCatData.loc[outCatData['name'] == i]['rate']:
        percDict[i] += p
        num += 1
        
    g = anaDF1.loc[anaDF1['Name'] == i]['Unique']
    
    domi = False
    if(g.iloc[0] - num == 1):
        domi = True
    
    vals = {'name': i, 'flaggedVals': num, 'totalVals': g.iloc[0], 'flaggedPerc': percDict[i], 'dominant': domi}
    outDescData = outDescData.append(vals, ignore_index=True)

outDescData
# Out:
#                                            name flaggedVals totalVals  \
# 0                             Accident_Severity           1         3
# 1                           Carriageway_Hazards           5         6
# 2   Did_Police_Officer_Attend_Scene_of_Accident           1         3
# 3                               Junction_Detail           2         9
# 4                              Light_Conditions           3         5
# 5             Pedestrian_Crossing-Human_Control           2         3
# 6       Pedestrian_Crossing-Physical_Facilities           2         6
# 7                       Road_Surface_Conditions           3         5
# 8                                     Road_Type           2         6
# 9                    Special_Conditions_at_Site           7         8
# 10                                  Speed_limit           3         5
# 11                           Weather_Conditions           6         9
#
#     flaggedPerc dominant
# 0      0.664856    False
# 1      0.618035     True
# 2      0.589943    False
# 3      1.526360    False
# 4      0.543122    False
# 5      0.177919     True
# 6      0.533758    False
# 7      0.861504    False
# 8      0.618035    False
# 9      1.114337     True
# 10     0.739770    False
# 11     2.050754    False

# %%
unFlagCatCol = categorCol - set(outDescData['name'].to_list())
unFlagCatCol
# Out:
# {'1st_Road_Class', 'Day_of_Week', 'Urban_or_Rural_Area'}

# %%
#creating a dataframe with all outliers and removing them from the data dataframe

outRecords = pd.DataFrame(columns = data.columns.to_list())

datDict = dict(data.dtypes)

for key, val in datDict.items():
    if val == 'int64' or val == 'float64':
        outRecords[key] = pd.to_numeric(outRecords[key])
        
#removing numeric outliers
for i in outNumData['name'].unique():
    upper = outNumData.loc[outNumData['name'] == i]['upper'].tolist()[0]
    lower = outNumData.loc[outNumData['name'] == i]['lower'].tolist()[0]
    outs = data.loc[(data[i] > upper) | (data[i] < lower)]
    data.drop(index = data.index[(data[i] > upper) | (data[i] < lower)].tolist(), inplace = True)
    outRecords = pd.concat([outRecords, outs])
    
    
print(data.shape)
print(outRecords.shape)
# Out:
# (10235, 28)
# (444, 28)

# %%
#removing categorical outliers
for i in outCatData['name'].unique():
    vals = outCatData.loc[outCatData['name'] == i]['value'].tolist()
    for v in vals:
        outs = data.loc[data[i] == v]
        data.drop(index = data.index[data[i] == v].tolist(), inplace = True)
        outRecords = pd.concat([outRecords, outs])
        
print(data.shape)
print(outRecords.shape)
# Out:
# (9374, 28)
# (1305, 28)

# %%
anaDF2 = analyzeDF(data)
anaDF2
# Out:
# (28, 8)
#                                            Name     Type Empty  Full  Ratio  \
# 0                                Accident_Index   object     0  9374    0.0
# 1                         Location_Easting_OSGR    int64     0  9374    0.0
# 2                        Location_Northing_OSGR    int64     0  9374    0.0
# 3                                     Longitude  float64     0  9374    0.0
# 4                                      Latitude  float64     0  9374    0.0
# 5                             Accident_Severity    int64     0  9374    0.0
# 6                            Number_of_Vehicles    int64     0  9374    0.0
# 7                          Number_of_Casualties    int64     0  9374    0.0
# 8                                   Day_of_Week    int64     0  9374    0.0
# 9                     Local_Authority_(Highway)   object     0  9374    0.0
# 10                               1st_Road_Class    int64     0  9374    0.0
# 11                              1st_Road_Number    int64     0  9374    0.0
# 12                                    Road_Type    int64     0  9374    0.0
# 13                                  Speed_limit    int64     0  9374    0.0
# 14                              Junction_Detail    int64     0  9374    0.0
# 15                              2nd_Road_Number    int64     0  9374    0.0
# 16            Pedestrian_Crossing-Human_Control    int64     0  9374    0.0
# 17      Pedestrian_Crossing-Physical_Facilities    int64     0  9374    0.0
# 18                             Light_Conditions    int64     0  9374    0.0
# 19                           Weather_Conditions    int64     0  9374    0.0
# 20                      Road_Surface_Conditions    int64     0  9374    0.0
# 21                   Special_Conditions_at_Site    int64     0  9374    0.0
# 22                          Carriageway_Hazards    int64     0  9374    0.0
# 23                          Urban_or_Rural_Area    int64     0  9374    0.0
# 24  Did_Police_Officer_Attend_Scene_of_Accident    int64     0  9374    0.0
# 25                    LSOA_of_Accident_Location   object     0  9374    0.0
# 26                                     DateVals    int64     0  9374    0.0
# 27                                     TimeVals    int64     0  9374    0.0
#
#          Min        Max Unique
# 0        Nan        Nan   9374
# 1     510800     535190   1815
# 2     175590     193940   1261
# 3  -0.401384  -0.049164   6445
# 4   51.46535  51.632397   6289
# 5          2          3      2
# 6          1          3      3
# 7          1          2      2
# 8          1          7      7
# 9        Nan        Nan      3
# 10         3          6      4
# 11         0       4140     56
# 12         1          6      4
# 13        30         40      2
# 14         0          8      7
# 15         0       4140     56
# 16         0          0      1
# 17         0          5      4
# 18         1          4      2
# 19         1          8      3
# 20         1          2      2
# 21         0          0      1
# 22         0          0      1
# 23         1          2      2
# 24         1          2      2
# 25       Nan        Nan    412
# 26         0       2190   2124
# 27         0       1438   1216

# %%
#droping all columns that only have 1 unique value
#the value in all the columsn was 0 signifying none, view document for extra info
print(data['Carriageway_Hazards'].unique())
print(data['Special_Conditions_at_Site'].unique())
print(data['Pedestrian_Crossing-Human_Control'].unique())

categorCol.remove('Carriageway_Hazards')
categorCol.remove('Pedestrian_Crossing-Human_Control')
categorCol.remove('Special_Conditions_at_Site')
# Out:
# [0]
# [0]
# [0]

# %%
data.drop(columns=['Carriageway_Hazards', 'Special_Conditions_at_Site', 'Pedestrian_Crossing-Human_Control'], inplace=True)
print(data.shape)
# Out:
# (9374, 25)

# %%
#exporting outlier free and clean data

data.to_csv(path_or_buf='/Users/othmanetazi/Desktop/DMA_ousework/processedData.csv', index = False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-30-6b6202ea540e> in <module>
#       1 #exporting outlier free and clean data
#       2
# ----> 3 data.to_csv(path_or_buf='/Users/othmanetazi/Desktop/DMA_ousework/processedData.csv', index = False)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/othmanetazi/Desktop/DMA_ousework/processedData.csv'

# %%
list(dict(data.dtypes).keys())

# %%
def bucketNumeric(datf, cols, bucket):
    outDF = pd.DataFrame()
    #refDF = pd.DataFrame()
    for col in datf.columns.to_list():
        if (col in cols):  
            spread = datf[col].max() - datf[col].min()
            mini = datf[col].min()
            vals = []
            for i in datf[col]:
                for x in range(bucket):
                    if( i - mini > (spread / bucket) * (x + 1)):
                        continue
                    else:
                        vals.append(x)
                        break
            outDF[col] = vals
        else:
            outDF[col] = datf[col]
            
    return outDF

# %%
len(data['DateVals'].unique())

# %%
def oneHotDF(datf, cols):
    outDF = pd.DataFrame()
    #refDF = pd.DataFrame()
    for col in datf.columns.to_list():
        if (col in cols):  
            colVals = list(datf[col].value_counts().keys())
            valList = {}
            for val in colVals:
                name = col + '_' + str(val)
                valList[name] = []
            for row in datf[col]:
                for i in colVals:
                    name = col + '_' + str(i)
                    if(i == row):
                        valList[name].append(1)
                    else:
                        valList[name].append(0)
            for k, v in valList.items():
                outDF[k] = v
        else:
            outDF[col] = datf[col]
            
    return outDF

# %%
list(data['Accident_Severity'].value_counts().keys())

# %%
impoCat = ['Accident_Severity', 'Day_of_Week', '1st_Road_Class', 'Junction_Detail', 'Speed_limit', 'Road_Type', 'Pedestrian_Crossing-Physical_Facilities', 'Light_Conditions', 'Weather_Conditions', 'Road_Surface_Conditions', 'Urban_or_Rural_Area', 'Did_Police_Officer_Attend_Scene_of_Accident']
impoNum = ['Number_of_Casulaties', 'Number_of_Vehicles', 'DateVals', 'TimeVals']

# %%
oheDF = oneHotDF(data, impoCat)
oheDF.to_csv(path_or_buf='/Users/othmanetazi/Desktop/DMA_ousework/processedOneHotData.csv', index = False)

# %%
oheDF.dtypes
